# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
df=pd.read_csv('pokemon_data.csv')
# print(df.head())
# print(df.tail(3))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# ...

# %%
## read headers
    # print(df.columns)

# ## read columns
    # print(df['Name'])
    # print(df.Name)
    # print(df.iloc[2,1])

## read each row using iterator
    # for index, row in df.iterrows():
    #     print(index,row['Name'])
# OR 
    # for index, row in df.iterrows():
    #     print(index,row)

# look for a specific value using loc
    
    # df.loc[df['Type 1']=="Fire"]
    
    
# df.describe()

# Sort ascending 1 column
# df.sort_values('Name')

# Sort desc 1 column
# df.sort_values('Name',ascending=False)

# Sort desc multiple columns 
df.sort_values(['Type 1','HP'],ascending=[1,0])
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
# add columns together
# df['Total']=df['HP']+df['Attack']+df['Defense']

# or another way is to drop some columns and then add the columns that you want
# df=df.drop(columns=['Total'])
# : = all rows and the 4 through the 9 column; axis=1 means adding horizontally
df['Total']=df.iloc[:,4:10].sum(axis=1)
# df.head(5)

# get list of columns
# cols=df.columns.values
# df.head(5)

# a different way to reorder columns without typing all the column name is to just reference their location
cols=list(df.columns)
df=df[cols[0:4]+[cols[-1]]+cols[4:12]]
df.head()
# Out:
#    #                   Name Type 1  Type 2  Legendary  Total  HP  Attack  \
# 0  1              Bulbasaur  Grass  Poison      False    591  45      49
# 1  2                Ivysaur  Grass  Poison      False    750  60      62
# 2  3               Venusaur  Grass  Poison      False    970  80      82
# 3  3  VenusaurMega Venusaur  Grass  Poison      False   1170  80     100
# 4  4             Charmander   Fire     NaN      False    553  39      52
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0       49       65       65     45           1
# 1       63       80       80     60           1
# 2       83      100      100     80           1
# 3      123      122      120     80           1
# 4       43       60       50     65           1

# %%
# write new df to csv; index=False will get rid of the index column in the csv
df.to_csv('modified.csv',index=False)

#write to excel file
# df.to_excel('modified.xlsx',index=False)

# # '\t'is tab separator
# df.to_csv('modified.txt',index=False,sep='\t')

# %%
df.head()
# filtering multiple columns; | is the or symbol
new_df=df.loc[(df['Type 1']=='Grass')& (df['Type 2']=='Poison')&(df['HP']>70)]
# df.loc[(df['Type 1']=='Grass')| (df['Type 2']=='Poison')]

# df
# new_df=new_df.reset_index()

# will remove old index
new_df.reset_index(drop=True)
new_df
# Out:
#        #                   Name Type 1  Type 2  Legendary  Total   HP  Attack  \
# 2      3               Venusaur  Grass  Poison      False    970   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison      False   1170   80     100
# 50    45              Vileplume  Grass  Poison      False    930   75      80
# 77    71             Victreebel  Grass  Poison      False    910   80     105
# 652  591              Amoonguss  Grass  Poison      False    898  114      85
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation
# 2         83      100      100     80           1
# 3        123      122      120     80           1
# 50        85      110       90     50           1
# 77        65      100       70     70           1
# 652       70       85       80     30           5

# %%
# # to get a string that contains a word you want to filter on
# df.loc[df['Name'].str.contains('Mega')]
# to get a string that does NOT contain a word you want to filter on use the squiggly line
# df.loc[~df['Name'].str.contains('Mega')]

# use regular expressions for more complicated filtering; import re then call regex=True to use them
# import re
# df.loc[df['Type 1'].str.contains('Fire|Grass',regex=True)]

# only want name that begin with pi; the ^ symbol specifies beginning of line ad a-z means the rest of the words can be any letter
df.loc[df['Name'].str.contains('^pi[a-z]*',flags=re.I,regex=True)]
# Out:
#        #                 Name    Type 1    Type 2  Legendary  Total   HP  \
# 20    16               Pidgey    Normal    Flying      False    446   40
# 21    17            Pidgeotto    Normal    Flying      False    627   63
# 22    18              Pidgeot    Normal    Flying      False    857   83
# 23    18  PidgeotMega Pidgeot    Normal    Flying      False   1037   83
# 30    25              Pikachu  Electric       NaN      False    550   35
# 136  127               Pinsir       Bug       NaN      False    915   65
# 137  127    PinsirMega Pinsir       Bug    Flying      False   1095   65
# 186  172                Pichu  Electric       NaN      False    350   20
# 219  204               Pineco       Bug       NaN      False    565   50
# 239  221            Piloswine       Ice    Ground      False    850  100
# 438  393               Piplup     Water       NaN      False    588   53
# 558  499              Pignite      Fire  Fighting      False    781   90
# ...

# %%
#rename values in a specific column where type is Fire, rename to flamer
df.loc[df['Type 1']=='Fire','Type 1']='Flamer'
df
# change it back
df.loc[df['Type 1']=='Flamer','Type 1']='Fire'
df

# You can use 1 condition to set the parameter of another column
df.loc[df['Type 1']=='Fire','Legendary']='True'
df
# Out:
#        #                   Name   Type 1  Type 2 Legendary  Total  HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison     False    591  45      49
# 1      2                Ivysaur    Grass  Poison     False    750  60      62
# 2      3               Venusaur    Grass  Poison     False    970  80      82
# 3      3  VenusaurMega Venusaur    Grass  Poison     False   1170  80     100
# 4      4             Charmander     Fire     NaN      True    553  39      52
# ..   ...                    ...      ...     ...       ...    ...  ..     ...
# 795  719                Diancie     Rock   Fairy      True   1150  50     100
# 796  719    DiancieMega Diancie     Rock   Fairy      True   1290  50     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost      True   1130  80     110
# 798  720     HoopaHoopa Unbound  Psychic    Dark      True   1280  80     160
# 799  721              Volcanion     Fire   Water      True   1130  80     110
#
# ...

# %%
# change multiple column values; change the values of generation and legend
# df.loc[df['Total']>500,['Generation','Legendary']]=['Test 1','Test 2']

# %%
# read in your saved dataframe checkpoint if you've messed it up 
# df=pd.read_csv('modified.csv')

# # Sums, Means, Counts
# df.groupby(['Type 1']).mean()
# df.groupby(['Type 1']).mean().sort_values('Defense',ascending=False)
# df.groupby(['Type 1']).sum()
# df.groupby(['Type 1']).count()
#53:42 on the video

#group by multiple columns
df.groupby(['Type 1','Type 2']).count()
# Out:
#                   #  Name  Legendary  Total  HP  Attack  Defense  Sp. Atk  \
# Type 1 Type 2
# Bug    Electric   2     2          2      2   2       2        2        2
#        Fighting   2     2          2      2   2       2        2        2
#        Fire       2     2          2      2   2       2        2        2
#        Flying    14    14         14     14  14      14       14       14
#        Ghost      1     1          1      1   1       1        1        1
# ...              ..   ...        ...    ...  ..     ...      ...      ...
# Water  Ice        3     3          3      3   3       3        3        3
#        Poison     3     3          3      3   3       3        3        3
#        Psychic    5     5          5      5   5       5        5        5
#        Rock       4     4          4      4   4       4        4        4
#        Steel      1     1          1      1   1       1        1        1
#
#                  Sp. Def  Speed  Generation
# Type 1 Type 2
# ...

# %% [markdown]
# ## School Summary

# %%
#working with really big files, load data in chunks; chunksize below is # of rows
for df in pd.read_csv('modified.csv',chunksize=5):
    print("CHUNK DF")
    print(df)
# see the data below in chunks of 5 rows at at time
# Out:
# CHUNK DF
#    #                   Name Type 1  Type 2  Legendary  Total  HP  Attack  \
# 0  1              Bulbasaur  Grass  Poison      False    591  45      49
# 1  2                Ivysaur  Grass  Poison      False    750  60      62
# 2  3               Venusaur  Grass  Poison      False    970  80      82
# 3  3  VenusaurMega Venusaur  Grass  Poison      False   1170  80     100
# 4  4             Charmander   Fire     NaN      False    553  39      52
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0       49       65       65     45           1
# 1       63       80       80     60           1
# 2       83      100      100     80           1
# 3      123      122      120     80           1
# 4       43       60       50     65           1
# CHUNK DF
#    #                       Name Type 1  Type 2  Legendary  Total  HP  Attack  \
# 5  5                 Charmeleon   Fire     NaN      False    730  58      64
# ...

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type
